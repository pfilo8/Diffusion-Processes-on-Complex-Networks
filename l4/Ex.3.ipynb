# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

from main3 import random_walk_on_graph, list_without_elements

# %%
N = 20
MAX_STEPS = 10000
N_SIMULATIONS = 100

SOURCE_NODE = 0
TARGET_NODES = list_without_elements(N, SOURCE_NODE)

# %%
def plot_graph(g, source_node):
    plt.figure(figsize = (12, 8))

    pos = nx.spring_layout(g)
    nx.draw_networkx(g, pos = pos)
    nx.draw_networkx_nodes(g, pos = pos, nodelist = [source_node], node_color = 'red')

def conduct_experiment(g):
    for node in TARGET_NODES:
        results = np.array([random_walk_on_graph(g, SOURCE_NODE, node) for _ in range(N_SIMULATIONS)])
        print(f'Path from {SOURCE_NODE} to {node} takes: {results[~np.isnan(results)].mean()} time steps.')

# %% [markdown]
# # Complete Graph

# %%
g = nx.complete_graph(N)
plot_graph(g, SOURCE_NODE)
# Out:
# /home/pwielopolski/anaconda3/envs/datascience/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
conduct_experiment(g)
# Out:
# Path from 0 to 1 takes: 17.08 time steps.
# Path from 0 to 2 takes: 15.71 time steps.
# Path from 0 to 3 takes: 18.38 time steps.
# Path from 0 to 4 takes: 16.21 time steps.
# Path from 0 to 5 takes: 15.01 time steps.
# Path from 0 to 6 takes: 17.6 time steps.
# Path from 0 to 7 takes: 16.29 time steps.
# Path from 0 to 8 takes: 16.66 time steps.
# Path from 0 to 9 takes: 16.48 time steps.
# Path from 0 to 10 takes: 17.49 time steps.
# Path from 0 to 11 takes: 18.22 time steps.
# Path from 0 to 12 takes: 18.72 time steps.
# Path from 0 to 13 takes: 21.15 time steps.
# Path from 0 to 14 takes: 20.21 time steps.
# Path from 0 to 15 takes: 19.64 time steps.
# Path from 0 to 16 takes: 16.29 time steps.
# Path from 0 to 17 takes: 19.49 time steps.
# Path from 0 to 18 takes: 18.51 time steps.
# Path from 0 to 19 takes: 18.9 time steps.

# %% [markdown]
# # Erdos Renyi Graph

# %%
g = nx.erdos_renyi_graph(20, 0.3)
plot_graph(g, SOURCE_NODE)

# %%
conduct_experiment(g)
# Out:
# Path from 0 to 1 takes: 13.4 time steps.
# Path from 0 to 2 takes: 12.46 time steps.
# Path from 0 to 3 takes: 23.27 time steps.
# Path from 0 to 4 takes: 24.47 time steps.
# Path from 0 to 5 takes: 11.4 time steps.
# Path from 0 to 6 takes: 23.91 time steps.
# Path from 0 to 7 takes: 22.99 time steps.
# Path from 0 to 8 takes: 36.54 time steps.
# Path from 0 to 9 takes: 17.02 time steps.
# Path from 0 to 10 takes: 16.97 time steps.
# Path from 0 to 11 takes: 19.16 time steps.
# Path from 0 to 12 takes: 25.07 time steps.
# Path from 0 to 13 takes: 14.6 time steps.
# Path from 0 to 14 takes: 26.48 time steps.
# Path from 0 to 15 takes: 19.96 time steps.
# Path from 0 to 16 takes: 31.05 time steps.
# Path from 0 to 17 takes: 33.02 time steps.
# Path from 0 to 18 takes: 23.17 time steps.
# Path from 0 to 19 takes: 45.05 time steps.

# %% [markdown]
# # Watts Strogatz Graph

# %%
g = nx.watts_strogatz_graph(20, 4, 0.3)
plot_graph(g, SOURCE_NODE)

# %%
conduct_experiment(g)
# Out:
# Path from 0 to 1 takes: 47.63 time steps.
# Path from 0 to 2 takes: 27.59 time steps.
# Path from 0 to 3 takes: 46.29 time steps.
# Path from 0 to 4 takes: 30.75 time steps.
# Path from 0 to 5 takes: 31.61 time steps.
# Path from 0 to 6 takes: 52.64 time steps.
# Path from 0 to 7 takes: 56.14 time steps.
# Path from 0 to 8 takes: 49.32 time steps.
# Path from 0 to 9 takes: 30.02 time steps.
# Path from 0 to 10 takes: 29.4 time steps.
# Path from 0 to 11 takes: 13.22 time steps.
# Path from 0 to 12 takes: 14.58 time steps.
# Path from 0 to 13 takes: 30.62 time steps.
# Path from 0 to 14 takes: 14.89 time steps.
# Path from 0 to 15 takes: 25.6 time steps.
# Path from 0 to 16 takes: 40.14 time steps.
# Path from 0 to 17 takes: 20.41 time steps.
# Path from 0 to 18 takes: 19.14 time steps.
# Path from 0 to 19 takes: 27.23 time steps.
